# %% [markdown]
# <a href="https://colab.research.google.com/github/Nadhim/ML-Lab/blob/main/Medical_Cost_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12.0, 9.0)

# %%
data = pd.read_csv('/content/insurance.csv')

X= data.iloc[:100,2].values # BMI

Y = data.iloc[:100,-1].values #Medical Insurance Claimed

plt.scatter(X,Y)
plt.xlabel("BMI")
plt.ylabel("Medical Cost")
# Out:
# Text(0, 0.5, 'Medical Cost')

# %%
m = 0
c = 0

L = 0.0001  # The learning Rate
epochs = 2  # The number of iterations to perform gradient descent

n = float(len(X)) # Number of elements in X

# Performing Gradient Descent
for i in range(epochs):
    Y_pred = m*X + c  # The current predicted value of Y
    D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(Y - Y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c

print (m, c)
# Out:
# 167.5936161871387 5.261113730277195

# %%
Y_pred = m*X + c

plt.scatter(X, Y)
plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red')  # regression line
plt.xlabel("BMI")
plt.ylabel("Medical Cost")

# plt.show()
# Out:
# Text(0, 0.5, 'Medical Cost')
